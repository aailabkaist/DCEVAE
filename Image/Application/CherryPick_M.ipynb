# %%
hyper_mCEVAE = 'u_dim_10_1.0_40.0_1.0_5.0'
hyper_DCEVAE = 'ud_ur_dim_5_5_1.00_40.00_1.00_3.20'
hyper_CEVAE = 'u_dim_10_1.0_40.0_1.0'

# %%
import os
real = os.path.join('mCEVAE', hyper_mCEVAE, 'M1', 'real')
mCEVAE = os.path.join('mCEVAE', hyper_mCEVAE, 'M1', 'cf')
DCEVAE = os.path.join('DCEVAE', hyper_DCEVAE, 'M1', 'cf')
CEVAE = os.path.join('CEVAE', hyper_CEVAE, 'M1', 'cf')

# %%
from IPython.display import Image, display

for i in range(1000,1010):
    real = os.path.join('mCEVAE', hyper_mCEVAE, 'M1', 'real')
    mCEVAE = os.path.join('mCEVAE', hyper_mCEVAE, 'M1', 'cf')
    DCEVAE = os.path.join('DCEVAE', hyper_DCEVAE, 'M1', 'cf')
    CEVAE = os.path.join('CEVAE', hyper_CEVAE, 'M1', 'cf')
    
    real_img = os.path.join(real, str(i)+'.jpg')
    mCEVAE_img = os.path.join(mCEVAE, str(i)+'.jpg')
    DCEVAE_img = os.path.join(DCEVAE, str(i)+'.jpg')
    CEVAE_img = os.path.join(CEVAE, str(i)+'.jpg')
    print('img ', i)
    print(DCEVAE_img)
    
    if os.path.exists(real_img):
        display(Image(filename=real_img))
        print('real')
      
    if os.path.exists(mCEVAE_img):
        display(Image(filename=mCEVAE_img))
        print('mCEVAE')
        
    if os.path.exists(DCEVAE_img):
        display(Image(filename=DCEVAE_img))
        print('DCEVAE')
        
    if os.path.exists(CEVAE_img):
        display(Image(filename=CEVAE_img))
        print('CEVAE')
# Out:
# img  1000
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1000.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1001
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1001.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1002
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1002.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1003
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1003.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1004
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1004.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1005
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1005.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1006
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1006.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1007
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1007.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1008
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1008.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
# img  1009
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/M1/cf/1009.jpg
# real
# mCEVAE
# DCEVAE
# CEVAE
