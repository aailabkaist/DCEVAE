# %%
hyper_mCEVAE = 'u_dim_10_1.0_40.0_1.0_5.0'
hyper_DCEVAE = 'ud_ur_dim_5_5_1.00_40.00_1.00_3.20'
hyper_CEVAE = 'u_dim_10_1.0_40.0_1.0'

# %%
import os
real = os.path.join('mCEVAE', hyper_mCEVAE, 'S1', 'real')
mCEVAE = os.path.join('mCEVAE', hyper_mCEVAE, 'S1', 'cf')
DCEVAE = os.path.join('DCEVAE', hyper_DCEVAE, 'S1', 'cf')
CEVAE = os.path.join('CEVAE', hyper_CEVAE, 'S1', 'cf')

# %%
from IPython.display import Image, display

for i in range(2500,3000):
    real = os.path.join('mCEVAE', hyper_mCEVAE, 'S1', 'real')
    mCEVAE = os.path.join('mCEVAE', hyper_mCEVAE, 'S1', 'cf')
    DCEVAE = os.path.join('DCEVAE', hyper_DCEVAE, 'S1', 'cf')
    CEVAE = os.path.join('CEVAE', hyper_CEVAE, 'S1', 'cf')
    
    real_img = os.path.join(real, str(i)+'.jpg')
    mCEVAE_img = os.path.join(mCEVAE, str(i)+'.jpg')
    DCEVAE_img = os.path.join(DCEVAE, str(i)+'.jpg')
    CEVAE_img = os.path.join(CEVAE, str(i)+'.jpg')
    print('img ', i)
    print(DCEVAE_img)
    
    if os.path.exists(real_img):
        display(Image(filename=real_img))
        print('real')
      
    #if os.path.exists(mCEVAE_img):
        #display(Image(filename=mCEVAE_img))
        #print('mCEVAE')
        
    #if os.path.exists(DCEVAE_img):
        #display(Image(filename=DCEVAE_img))
        #print('DCEVAE')
        
    #if os.path.exists(CEVAE_img):
        #display(Image(filename=CEVAE_img))
        #print('CEVAE')
# Out:
# img  2500
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2500.jpg
# real
# img  2501
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2501.jpg
# real
# img  2502
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2502.jpg
# real
# img  2503
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2503.jpg
# real
# img  2504
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2504.jpg
# real
# img  2505
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2505.jpg
# real
# img  2506
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2506.jpg
# real
# img  2507
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2507.jpg
# real
# img  2508
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2508.jpg
# real
# img  2509
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2509.jpg
# real
# img  2510
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2510.jpg
# real
# img  2511
# DCEVAE/ud_ur_dim_5_5_1.00_40.00_1.00_3.20/S1/cf/2511.jpg
# real
# img  2512
# ...
